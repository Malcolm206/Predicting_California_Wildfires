# %%
import pandas as pd
pd.set_option('display.max_columns', 200) #set to show all columns
pd.set_option('display.max_rows', 200) 
from glob import glob
import numpy as np

# %%
ground_cover = pd.DataFrame()

# %%
filenames = glob('data/ground_cover_2013/*.csv')
filenames.sort()
filenames
# Out:
# ['data/ground_cover_2013/AlamedaCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/AlpineCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/AmadorCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/ButteCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/CalaverasCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/ColusaCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/Contra CostaCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/Del NorteCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/El DoradoCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/FresnoCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/GlennCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/HumboldtCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/ImperialCrop_Summary_Data_2020_11_27.csv',
#  'data/ground_cover_2013/InyoCrop_Summary_Data_2020_11_27.csv',
# ...

# %%
d = {}
for x in range(0, len(filenames)):
    d[filenames[x]]= pd.read_csv(filenames[x])

# %%
d[filenames[1]]
# Out:
#     OBJECTID  County                     Class  Count_           Sum_  \
# 0         24  Alpine             Alfalfa & Hay       7     189.035750
# 1         25  Alpine                    Barren      19   15482.472715
# 2         26  Alpine          Deciduous Forest       7     194.595625
# 3         27  Alpine          Evergreen Forest     156  195088.007530
# 4         28  Alpine                    Fallow       1       0.444790
# 5         29  Alpine               Fruit Trees       1       0.222395
# 6         30  Alpine                 Grassland     141    5644.829890
# 7         31  Alpine  High Intensity Developed      25     121.427670
# 8         32  Alpine   Low Intensity Developed     171    3192.480225
# 9         33  Alpine              Mixed Forest       1       0.667185
# 10        34  Alpine                 Shrubland     260  247783.390805
# 11        35  Alpine                     Water      15    2650.503610
# ...

# %%
counties_list = ['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa', 'Contra Costa', 'Del Norte', 
                 'El Dorado', 'Fresno', 'Glenn', 'Humboldt', 'Imperial', 'Inyo', 'Kern','Kings', 'Lake', 
                 'Lassen', 'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino', 'Merced', 'Modoc', 'Mono',
                 'Monterey', 'Napa', 'Nevada', 'Orange', 'Placer', 'Plumas', 'Riverside', 'Sacramento', 
                 'San Benito', 'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin', 'San Luis Obispo', 
                 'San Mateo', 'Santa Barbara', 'Santa Clara', 'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 
                 'Solano', 'Sonoma', 'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne', 
                 'Ventura', 'Yolo', 'Yuba']

# %%
df1 = pd.read_csv('data/ground_cover_2013/AlamedaCrop_Summary_Data_2020_11_27.csv')

# %%
df1.drop(columns = ['OBJECTID', 'County', 'Count_', 'Min_', 'Max_', 'Mean', 'Perc25th', 'Median', 'Perc75th', 
                    'Perc95th', 'PercentMaxOwnerCounty', 'Gini', 'label', 'data', 'color'], inplace = True)

# %%
df1 = df1.T

# %%
df1
# Out:
#                            0            1           2            3  \
# Class          Alfalfa & Hay      Almonds      Barren         Corn
# Sum_                 1102.86      4.22551     194.596      4.67029
# PercentCounty     0.00300074  1.14971e-05  0.00052947  1.27073e-05
#
#                               4                 5          6            7  \
# Class          Deciduous Forest  Evergreen Forest     Fallow  Fruit Trees
# Sum_                    5.33748           7838.76    1536.75      1.77916
# PercentCounty       1.45226e-05         0.0213283  0.0041813  4.84087e-06
#
#                          8          9         10                        11  \
# Class          Grain Crops     Grapes  Grassland  High Intensity Developed
# Sum_               991.215    3722.45     153671                   28431.4
# PercentCounty   0.00269697  0.0101283   0.418121                 0.0773583
#
#                                     12            13                14  \
# ...

# %%
df1a = df1
df1a.columns = df1.iloc[0]
df1a = df1.iloc[1:]
df1a = df1a.reset_index(drop = True)

# %%
df1a
# Out:
# Class Alfalfa & Hay      Almonds      Barren         Corn Deciduous Forest  \
# 0           1102.86      4.22551     194.596      4.67029          5.33748
# 1        0.00300074  1.14971e-05  0.00052947  1.27073e-05      1.45226e-05
#
# Class Evergreen Forest     Fallow  Fruit Trees Grain Crops     Grapes  \
# 0              7838.76    1536.75      1.77916     991.215    3722.45
# 1            0.0213283  0.0041813  4.84087e-06  0.00269697  0.0101283
#
# Class Grassland High Intensity Developed Low Intensity Developed Mixed Forest  \
# 0        153671                  28431.4                 39470.9        74886
# 1      0.418121                0.0773583                0.107395     0.203755
#
# Class Other Tree Crops         Rice Shrubland     Tomatoes Vegs & Fruits  \
# 0              8.67341      0.88958   30958.1      4.67029       164.128
# 1          2.35992e-05  2.42044e-06  0.084233  1.27073e-05    0.00044657
#
# Class      Walnuts      Water   Wetlands Winter Wheat
# ...

# %%
df1b = pd.DataFrame(columns = df1.iloc[0])
df1b
# Out:
# Empty DataFrame
# Columns: [Alfalfa & Hay, Almonds, Barren, Corn, Deciduous Forest, Evergreen Forest, Fallow, Fruit Trees, Grain Crops, Grapes, Grassland, High Intensity Developed, Low Intensity Developed, Mixed Forest, Other Tree Crops, Rice, Shrubland, Tomatoes, Vegs & Fruits, Walnuts, Water, Wetlands, Winter Wheat]
# Index: []

# %%
df1b = df1b.append(df1a.loc[0])
df1b
# Out:
# Class  Alfalfa & Hay   Almonds      Barren      Corn  Deciduous Forest  \
# 0        1102.856805  4.225505  194.595625  4.670295           5.33748
#
# Class  Evergreen Forest      Fallow  Fruit Trees  Grain Crops      Grapes  \
# 0           7838.756565  1536.74945      1.77916   991.214515  3722.44751
#
# Class     Grassland  High Intensity Developed  Low Intensity Developed  \
# 0      153671.38668               28431.42159             39470.886995
#
# Class  Mixed Forest  Other Tree Crops     Rice     Shrubland  Tomatoes  \
# 0      74885.956375          8.673405  0.88958  30958.051185  4.670295
#
# Class  Vegs & Fruits   Walnuts        Water     Wetlands  Winter Wheat
# 0          164.12751  4.670295  19403.51896  4497.494085     624.48516

# %%
df1b.columns = df1b.columns + '_acres'
df1b
# Out:
# Class  Alfalfa & Hay_acres  Almonds_acres  Barren_acres  Corn_acres  \
# 0              1102.856805       4.225505    194.595625    4.670295
#
# Class  Deciduous Forest_acres  Evergreen Forest_acres  Fallow_acres  \
# 0                     5.33748             7838.756565    1536.74945
#
# Class  Fruit Trees_acres  Grain Crops_acres  Grapes_acres  Grassland_acres  \
# 0                1.77916         991.214515    3722.44751     153671.38668
#
# Class  High Intensity Developed_acres  Low Intensity Developed_acres  \
# 0                         28431.42159                   39470.886995
#
# Class  Mixed Forest_acres  Other Tree Crops_acres  Rice_acres  \
# 0            74885.956375                8.673405     0.88958
#
# Class  Shrubland_acres  Tomatoes_acres  Vegs & Fruits_acres  Walnuts_acres  \
# 0         30958.051185        4.670295            164.12751       4.670295
#
# Class  Water_acres  Wetlands_acres  Winter Wheat_acres
# ...

# %%
df1c = pd.DataFrame(columns = df1.iloc[0])
df1c = df1c.append(df1a.loc[1] * 100)
df1c.columns = df1c.columns + '_percentage'
df1c
# Out:
# Class  Alfalfa & Hay_percentage  Almonds_percentage  Barren_percentage  \
# 1                      0.300074             0.00115           0.052947
#
# Class  Corn_percentage  Deciduous Forest_percentage  \
# 1             0.001271                     0.001452
#
# Class  Evergreen Forest_percentage  Fallow_percentage  Fruit Trees_percentage  \
# 1                         2.132827            0.41813                0.000484
#
# Class  Grain Crops_percentage  Grapes_percentage  Grassland_percentage  \
# 1                    0.269697           1.012831             41.812059
#
# Class  High Intensity Developed_percentage  \
# 1                                 7.735834
#
# Class  Low Intensity Developed_percentage  Mixed Forest_percentage  \
# 1                               10.739534                20.375531
#
# Class  Other Tree Crops_percentage  Rice_percentage  Shrubland_percentage  \
# 1                          0.00236         0.000242              8.423298
#
# ...

# %%
df1d = pd.concat([df1b, df1c], axis = 1)

# %%
df1d
# Out:
# Class  Alfalfa & Hay_acres  Almonds_acres  Barren_acres  Corn_acres  \
# 0              1102.856805       4.225505    194.595625    4.670295
# 1                      NaN            NaN           NaN         NaN
#
# Class  Deciduous Forest_acres  Evergreen Forest_acres  Fallow_acres  \
# 0                     5.33748             7838.756565    1536.74945
# 1                         NaN                     NaN           NaN
#
# Class  Fruit Trees_acres  Grain Crops_acres  Grapes_acres  Grassland_acres  \
# 0                1.77916         991.214515    3722.44751     153671.38668
# 1                    NaN                NaN           NaN              NaN
#
# Class  High Intensity Developed_acres  Low Intensity Developed_acres  \
# 0                         28431.42159                   39470.886995
# 1                                 NaN                            NaN
#
# Class  Mixed Forest_acres  Other Tree Crops_acres  Rice_acres  \
# ...

# %%
df1d.loc[2] = df1d.sum()
df1d
# Out:
# Class  Alfalfa & Hay_acres  Almonds_acres  Barren_acres  Corn_acres  \
# 0              1102.856805       4.225505    194.595625    4.670295
# 1                      NaN            NaN           NaN         NaN
# 2              1102.856805       4.225505    194.595625    4.670295
#
# Class  Deciduous Forest_acres  Evergreen Forest_acres  Fallow_acres  \
# 0                     5.33748             7838.756565    1536.74945
# 1                         NaN                     NaN           NaN
# 2                     5.33748             7838.756565    1536.74945
#
# Class  Fruit Trees_acres  Grain Crops_acres  Grapes_acres  Grassland_acres  \
# 0                1.77916         991.214515    3722.44751     153671.38668
# 1                    NaN                NaN           NaN              NaN
# 2                1.77916         991.214515    3722.44751     153671.38668
#
# Class  High Intensity Developed_acres  Low Intensity Developed_acres  \
# ...

# %%
df1d = df1d.iloc[2:]

# %%
df1d
# Out:
# Class  Alfalfa & Hay_acres  Almonds_acres  Barren_acres  Corn_acres  \
# 2              1102.856805       4.225505    194.595625    4.670295
#
# Class  Deciduous Forest_acres  Evergreen Forest_acres  Fallow_acres  \
# 2                     5.33748             7838.756565    1536.74945
#
# Class  Fruit Trees_acres  Grain Crops_acres  Grapes_acres  Grassland_acres  \
# 2                1.77916         991.214515    3722.44751     153671.38668
#
# Class  High Intensity Developed_acres  Low Intensity Developed_acres  \
# 2                         28431.42159                   39470.886995
#
# Class  Mixed Forest_acres  Other Tree Crops_acres  Rice_acres  \
# 2            74885.956375                8.673405     0.88958
#
# Class  Shrubland_acres  Tomatoes_acres  Vegs & Fruits_acres  Walnuts_acres  \
# 2         30958.051185        4.670295            164.12751       4.670295
#
# Class  Water_acres  Wetlands_acres  Winter Wheat_acres  \
# ...

# %%
ground_cover = ground_cover.append(df1d)

# %%
ground_cover
# Out:
# Class  Alfalfa & Hay_acres  Almonds_acres  Barren_acres  Corn_acres  \
# 2              1102.856805       4.225505    194.595625    4.670295
#
# Class  Deciduous Forest_acres  Evergreen Forest_acres  Fallow_acres  \
# 2                     5.33748             7838.756565    1536.74945
#
# Class  Fruit Trees_acres  Grain Crops_acres  Grapes_acres  Grassland_acres  \
# 2                1.77916         991.214515    3722.44751     153671.38668
#
# Class  High Intensity Developed_acres  Low Intensity Developed_acres  \
# 2                         28431.42159                   39470.886995
#
# Class  Mixed Forest_acres  Other Tree Crops_acres  Rice_acres  \
# 2            74885.956375                8.673405     0.88958
#
# Class  Shrubland_acres  Tomatoes_acres  Vegs & Fruits_acres  Walnuts_acres  \
# 2         30958.051185        4.670295            164.12751       4.670295
#
# Class  Water_acres  Wetlands_acres  Winter Wheat_acres  \
# ...

# %%
def ground_cover_table(dictionary, files):
    ground_cover = pd.DataFrame()
    for x in range(0, 58):
        df = dictionary[files[x]]
        df.drop(columns = ['OBJECTID', 'County', 'Count_', 'Min_', 'Max_', 'Mean', 'Perc25th', 'Median', 'Perc75th', 
                    'Perc95th', 'PercentMaxOwnerCounty', 'Gini', 'label', 'data', 'color'], inplace = True)
        df.dropna(inplace=True)
        df = df.T
        df1a = df
        df1a.columns = df.iloc[0]
        df1a = df.iloc[1:]
        df1a = df1a.reset_index(drop = True)
        df1b = pd.DataFrame(columns = df.iloc[0])
        df1b = df1b.append(df1a.loc[0])
        df1b.columns = df1b.columns + '_acres'
        df1c = pd.DataFrame(columns = df.iloc[0])
        df1c = df1c.append(df1a.loc[1] * 100)
        df1c.columns = df1c.columns + '_percentage'
        df1d = pd.concat([df1b, df1c], axis = 1)
        df1d.loc[2] = df1d.sum()
        df1d = df1d.iloc[2:]
        ground_cover = ground_cover.append(df1d)
    return ground_cover

# %%
ground_cover_counties = ground_cover_table(d, filenames)
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
ground_cover_counties
# Out:
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2          1102.856805                  0.300074       4.225505
# 2           189.035750                  0.040080            NaN
# 2          1326.808570                  0.414290      16.679625
# 2          3777.156680                  0.374865   46196.556585
# 2            31.802485                  0.005011      28.466560
# 2         14434.547475                  1.992021   47220.463165
# 2          8448.341260                  4.582245      62.492995
# 2                  NaN                       NaN            NaN
# 2             5.115085                  0.000488            NaN
# 2         85527.334730                  2.447318  211666.220410
# 2         18760.352620                  2.327644   45937.688805
# 2          2065.604760                  0.108404            NaN
# 2        203684.019070                  7.306178     524.852200
# 2          1782.718320                  0.027323            NaN
# ...

# %%
min_elevation = [-42, 1442, 43, -1, 787, -9, -30, 120, 145, 47, 2, 27, -81, -96, 58, 46, 18, 1145, 69, 61, -53, 
                 269, 7, 2, 1271, 1283, 95, -32, 256, -16, 174, 978, -81, 27, 15, -3, -72, 30, 6, 56, -11, 14, 
                 -22, 16, 111, 658, 490, -22, -24, -2, 234, 50, 114, 149, 374, 34, -26, 199]

# %%
max_elevation = [1242, 3556, 3121, 2192, 3522, 1022, 680, 2215, 3299, 4153, 1756, 2709, 799, 3345, 2689, 524, 
                 2140, 2666, 3032, 3959, 577, 3952, 2252, 543, 3004, 4323, 1594, 84, 2784, 1732, 2787, 2543, 
                 3263, 1329, 1299, 3493, 1981, 667, 1889, 1538, 1317, 2693, 1316, 1153, 3159, 2687, 4294, 118, 
                 1438, 1026, 1652, 2444, 2450, 4409, 3959, 2332, 346, 2541]

# %%
ground_cover_counties['county'] = counties_list
ground_cover_counties['min_elevation'] = min_elevation
ground_cover_counties['max_elevation'] = max_elevation

# %%
ground_cover_counties['year'] = 2013

# %%
ground_cover_counties
# Out:
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2          1102.856805                  0.300074       4.225505
# 2           189.035750                  0.040080            NaN
# 2          1326.808570                  0.414290      16.679625
# 2          3777.156680                  0.374865   46196.556585
# 2            31.802485                  0.005011      28.466560
# 2         14434.547475                  1.992021   47220.463165
# 2          8448.341260                  4.582245      62.492995
# 2                  NaN                       NaN            NaN
# 2             5.115085                  0.000488            NaN
# 2         85527.334730                  2.447318  211666.220410
# 2         18760.352620                  2.327644   45937.688805
# 2          2065.604760                  0.108404            NaN
# 2        203684.019070                  7.306178     524.852200
# 2          1782.718320                  0.027323            NaN
# ...

# %%
ground_cover_counties.to_csv('data/gc_el_counties.csv')

# %%
filenames_2014 = glob('data/ground_cover_2014/*.csv')
filenames_2014.sort()
filenames_2014
# Out:
# ['data/ground_cover_2014/AlamedaCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/AlpineCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/AmadorCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/ButteCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/CalaverasCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/ColusaCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/Contra CostaCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/Del NorteCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/El DoradoCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/FresnoCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/GlennCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/HumboldtCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/ImperialCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2014/InyoCrop_Summary_Data_2020_12_3.csv',
# ...

# %%
d_2014 = {}
for x in range(0, len(filenames_2014)):
    d_2014[filenames_2014[x]]= pd.read_csv(filenames_2014[x])

# %%
ground_cover_counties_2014 = ground_cover_table(d_2014, filenames_2014)
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
ground_cover_counties_2014['county'] = counties_list
ground_cover_counties_2014['min_elevation'] = min_elevation
ground_cover_counties_2014['max_elevation'] = max_elevation
ground_cover_counties_2014['year'] = 2014

# %%
ground_cover_counties_2014
# Out:
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2          1279.883225                  0.348052     111.864685
# 2           544.200565                  0.115368            NaN
# 2          1681.750990                  0.525120      28.021770
# 2          4858.218775                  0.482155   42045.331515
# 2            85.622075                  0.013490      16.234835
# 2         13436.438715                  1.854278   52547.268205
# 2         15824.071435                  8.582619     609.584695
# 2           152.118180                  0.024067       0.222395
# 2            31.802485                  0.003033       0.222395
# 2         86999.144840                  2.489433  208455.948585
# 2         18017.330925                  2.235456   46533.485010
# 2          4833.755325                  0.253633       2.446345
# 2        234333.385995                  8.402415     353.163260
# 2          2607.581375                  0.039964            NaN
# ...

# %%
filenames_2015 = glob('data/ground_cover_2015/*.csv')
filenames_2015.sort()
filenames_2015
# Out:
# ['data/ground_cover_2015/AlamedaCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/AlpineCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/AmadorCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/ButteCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/CalaverasCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/ColusaCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/Contra CostaCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/Del NorteCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/El DoradoCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/FresnoCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/GlennCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/HumboldtCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/ImperialCrop_Summary_Data_2020_12_3.csv',
#  'data/ground_cover_2015/InyoCrop_Summary_Data_2020_12_3.csv',
# ...

# %%
d_2015 = {}
for x in range(0, len(filenames_2015)):
    d_2015[filenames_2015[x]]= pd.read_csv(filenames_2015[x])
ground_cover_counties_2015 = ground_cover_table(d_2015, filenames_2015)
ground_cover_counties_2015['county'] = counties_list
ground_cover_counties_2015['min_elevation'] = min_elevation
ground_cover_counties_2015['max_elevation'] = max_elevation
ground_cover_counties_2015['year'] = 2015
ground_cover_counties_2015
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2           833.536460                  0.226672      46.258160
# 2           304.236360                  0.064497            NaN
# 2          1124.429120                  0.351098      74.724720
# 2          5373.730385                  0.533317   50675.591885
# 2            45.146185                  0.007113     129.878680
# 2         13020.115275                  1.796824   51301.411415
# 2         10148.328640                  5.504224     136.105740
# 2          4575.777125                  0.723941            NaN
# ...

# %%
filenames_2016 = glob('data/ground_cover_2016/*.csv')
filenames_2016.sort()
filenames_2016
# Out:
# ['data/ground_cover_2016/AlamedaCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/AlpineCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/AmadorCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/ButteCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/CalaverasCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/ColusaCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/Contra CostaCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/Del NorteCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/El DoradoCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/FresnoCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/GlennCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/HumboldtCrop_Summary_Data_2020_12_3 (1).csv',
#  'data/ground_cover_2016/ImperialCrop_Summary_Data_2020_12_3 (1).csv',
# ...

# %%
d_2016 = {}
for x in range(0, len(filenames_2016)):
    d_2016[filenames_2016[x]]= pd.read_csv(filenames_2016[x])
ground_cover_counties_2016 = ground_cover_table(d_2016, filenames_2016)
ground_cover_counties_2016['county'] = counties_list
ground_cover_counties_2016['min_elevation'] = min_elevation
ground_cover_counties_2016['max_elevation'] = max_elevation
ground_cover_counties_2016['year'] = 2016
ground_cover_counties_2016
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2          1138.884795                  0.277948      63.827365
# 2           359.612715                  0.076246            NaN
# 2          1566.550380                  0.489149      57.600305
# 2          3504.945200                  0.347849   43919.676575
# 2            36.472780                  0.005746     108.306365
# 2         11288.770200                  1.557892   57285.171285
# 2         10438.331720                  5.628236     235.738700
# 2             1.111975                  0.000176            NaN
# ...

# %%
filenames_2017 = glob('data/ground_cover_2017/*.csv')
filenames_2017.sort()
filenames_2017
# Out:
# ['data/ground_cover_2017/AlamedaCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/AlpineCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/AmadorCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/ButteCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/CalaverasCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/ColusaCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/Contra CostaCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/Del NorteCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/El DoradoCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/FresnoCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/GlennCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/HumboldtCrop_Summary_Data_2020_12_3 (2).csv',
#  'data/ground_cover_2017/ImperialCrop_Summary_Data_2020_12_3 (2).csv',
# ...

# %%
d_2017 = {}
for x in range(0, len(filenames_2017)):
    d_2017[filenames_2017[x]]= pd.read_csv(filenames_2017[x])
ground_cover_counties_2017 = ground_cover_table(d_2017, filenames_2017)
ground_cover_counties_2017['county'] = counties_list
ground_cover_counties_2017['min_elevation'] = min_elevation
ground_cover_counties_2017['max_elevation'] = max_elevation
ground_cover_counties_2017['year'] = 2017
ground_cover_counties_2017
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2           900.477355                  0.219764      26.020215
# 2           382.964190                  0.081187            NaN
# 2          1629.265770                  0.508731      26.020215
# 2          5456.238930                  0.541506   29864.090180
# 2            59.601860                  0.009391      58.045095
# 2         12452.340840                  1.718469   63354.998020
# 2         11580.997230                  6.244349     559.323425
# 2             4.225505                  0.000668            NaN
# ...

# %%
filenames_2018 = glob('data/ground_cover_2018/*.csv')
filenames_2018.sort()
filenames_2018
# Out:
# ['data/ground_cover_2018/AlamedaCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/AlpineCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/AmadorCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/ButteCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/CalaverasCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/ColusaCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/Contra CostaCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/Del NorteCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/El DoradoCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/FresnoCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/GlennCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/HumboldtCrop_Summary_Data_2020_12_3 (3).csv',
#  'data/ground_cover_2018/ImperialCrop_Summary_Data_2020_12_3 (3).csv',
# ...

# %%
d_2018 = {}
for x in range(0, len(filenames_2018)):
    d_2018[filenames_2018[x]]= pd.read_csv(filenames_2018[x])
ground_cover_counties_2018 = ground_cover_table(d_2018, filenames_2018)
ground_cover_counties_2018['county'] = counties_list
ground_cover_counties_2018['min_elevation'] = min_elevation
ground_cover_counties_2018['max_elevation'] = max_elevation
ground_cover_counties_2018['year'] = 2018
ground_cover_counties_2018
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#    Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2          1487.377760                  0.404875      68.052870
# 2           700.989040                  0.148606            NaN
# 2          1739.128900                  0.543036      24.241055
# 2          5199.595100                  0.516035   36487.680465
# 2            60.269045                  0.009496       7.783825
# 2         13366.161895                  1.844580   54797.460815
# 2         10345.370610                  5.611583     152.785365
# 2             9.562985                  0.001514            NaN
# ...

# %%
ground_cover_counties = ground_cover_counties.append([ground_cover_counties_2014, 
                                                      ground_cover_counties_2015, 
                                                      ground_cover_counties_2016, 
                                                      ground_cover_counties_2017, 
                                                      ground_cover_counties_2018])
# Out:
# /Users/malcolmkatzenbach/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
ground_cover_counties
# Out:
#     Alfalfa & Hay_acres  Alfalfa & Hay_percentage  Almonds_acres  \
# 2           1102.856805                  0.300074       4.225505
# 2            189.035750                  0.040080            NaN
# 2           1326.808570                  0.414290      16.679625
# 2           3777.156680                  0.374865   46196.556585
# 2             31.802485                  0.005011      28.466560
# ..                  ...                       ...            ...
# 2          42714.518070                  1.418197   70462.742220
# 2             58.712280                  0.004171       3.335925
# 2           1149.114965                  0.106102       3.780715
# 2          49157.968405                  8.216211   28688.732605
# 2           4708.546940                  1.201779    1606.359085
#
#     Almonds_percentage   Barren_acres  Barren_percentage    Corn_acres  \
# 2             0.001150     194.595625           0.052947      4.670295
# ...

# %%
ground_cover_counties.to_csv('data/gc_el_counties_all_years.csv')
